# %% [markdown]
# ## MatplotLib Library

# %% [markdown]
# It is a data visualization library. For the installation in the command prompt write "pip install matplotlib"

# %% [markdown]
# #### Here we will be using two libraries Numpy and Matplotlib (Numpy for data generation , Matplotlib for data visualization)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# generating the random data
x_data = np.random.random(100)
y_data = np.random.random(100)

# %%
print(x_data)
print('---------------------------------------------------------------')
print(y_data)
# Out:
# [0.46822913 0.41238257 0.281488   0.72400775 0.29033239 0.27401324
#  0.7130311  0.34819088 0.50962924 0.4956016  0.81717857 0.16388546
#  0.44932305 0.27483517 0.39834812 0.91260306 0.56650105 0.97402825
#  0.93086235 0.34612602 0.04012791 0.66685    0.59488451 0.73319348
#  0.78790916 0.64099589 0.93901105 0.54721487 0.45466833 0.65658298
#  0.42455601 0.13013906 0.76351637 0.47280504 0.10476059 0.13051254
#  0.31696693 0.54680795 0.56604162 0.3542821  0.85726022 0.45775355
#  0.62112573 0.00890055 0.84440069 0.23142031 0.41466527 0.61557001
#  0.83708667 0.90333699 0.20142054 0.07125523 0.83728784 0.31927737
#  0.51073059 0.88852222 0.2360841  0.47596898 0.33806583 0.68141614
#  0.68835862 0.66228592 0.30800071 0.19734321 0.59176763 0.24773705
#  0.20820011 0.84462406 0.85500724 0.60268811 0.40772382 0.72932489
#  0.83264431 0.55198804 0.66607106 0.06819983 0.28518273 0.6940825
#  0.55011197 0.9428744  0.69363077 0.77318365 0.0412136  0.09970801
# ...

# %%
# multiplying the numbers by 100
x_data *=100
y_data *=100

# %%
print(x_data)
print('---------------------------------------------------------------')
print(y_data)
# Out:
# [46.82291329 41.23825714 28.14879967 72.4007751  29.03323929 27.40132414
#  71.30311019 34.81908816 50.96292354 49.56015986 81.7178573  16.38854607
#  44.93230483 27.48351663 39.83481157 91.26030553 56.65010511 97.40282534
#  93.08623534 34.61260175  4.01279124 66.68500047 59.48845066 73.31934798
#  78.79091616 64.09958898 93.90110538 54.721487   45.46683262 65.65829838
#  42.45560099 13.01390585 76.35163725 47.28050424 10.47605946 13.05125396
#  31.69669297 54.68079501 56.60416163 35.42821017 85.72602201 45.77535473
#  62.11257324  0.89005465 84.44006858 23.14203089 41.46652701 61.55700058
#  83.70866715 90.33369887 20.14205355  7.12552295 83.72878393 31.92773716
#  51.07305919 88.85222247 23.60840984 47.59689818 33.80658337 68.14161397
#  68.83586194 66.22859208 30.80007061 19.73432098 59.17676343 24.77370486
#  20.8200109  84.46240643 85.50072413 60.26881136 40.77238225 72.93248927
#  83.26443059 55.19880357 66.60710603  6.81998324 28.51827282 69.40825042
# ...

# %% [markdown]
# ### Scatter Plot (X , Y points plotted as points or we can say as markers)

# %%
plt.scatter(x_data,y_data)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X VS Y Scatter plot')
plt.show()

# %% [markdown]
# #### Scatter Plot Customizations

# %%
# changing color nd marker (using c attribute for color and marker attribute for marker)
plt.scatter(x_data,y_data,c='red',marker='*')
plt.show()

# %%
# Adding transparency for checking onerlapping alpha = 1 means most dark 0.5 means 50 percent light
plt.scatter(x_data,y_data,c='red',marker='*',alpha=.3)
plt.show()

# %%
# changing the size of the marker
plt.scatter(x_data,y_data,c='red',marker='*',alpha=0.5,s=100)
plt.show()

# %% [markdown]
# ### Line Plots
#
# ##### Line Plots are usefull when we have the time series data for example stock market analysis or weather analysis

# %%
# creating an years dataset using list comprehension
years = [2000+x for x in range(25)]
print(years)
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
# creating the weights data from the range 70 to 90 intotal 25 
weights = np.random.randint(70,90,25,dtype=int)
print(weights)
# Out:
# [86 71 79 78 77 88 78 73 86 87 73 86 80 85 79 76 86 71 86 89 78 83 85 72
#  78]

# %%
plt.plot(years,weights)
plt.xlabel('Years')
plt.ylabel('Weight(Kgs)')
plt.title('Weight Analysis per Year')
plt.show()

# %% [markdown]
# ### Line Plot Customizations

# %%
# for changing color 
plt.plot(years,weights,color='cyan')
plt.show()

# %%
# changing the linewidth
plt.plot(years,weights,color='red',linewidth=3)
plt.show()

# %%
# adding markers to the corners
plt.plot(years,weights,color='red',linewidth=3,marker='+',markersize=10)
plt.show()

# %%
# adding line style   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...} in docs shift+tab
plt.plot(years,weights,color='red',linewidth=3,marker='+',markersize=10,ls='--')
plt.show()

# %% [markdown]
# ### Barplots

# %% [markdown]
# ##### Barplots are usefull for showing the categorical count plots

# %%
languages = ['C','C++','Java','Python']
votes = [10,30,10,50]

# %%
plt.bar(languages,votes)
plt.xlabel('Languages')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### Note : Bar plot must not be confused with histogram because the bar plot have spaces in between and histogram does not have the spaces. Also histogram is usefull in showing the frequency count.

# %% [markdown]
# ### Barplot Customizations

# %%
# changing color and adding edge color
plt.bar(languages,votes,color='cyan',edgecolor='red')
plt.xlabel('Languages')
plt.ylabel('Count')
plt.show()

# %%
# changing the width of the bar , maxwidth is 1 (0.0 to 1.0)
plt.bar(languages,votes,width=0.5)
plt.show()

# %%
# align labels at the edge of the bar  {'center', 'edge'}, default: 'center'
plt.bar(languages,votes,align='edge')
plt.show()

# %% [markdown]
# ### Histograms
#
# ##### Histograms are usefull in showing the frequency count of the values in the data i.e. how many times that value occured in the data.

# %%
ages = np.random.normal(20,2,100)
print(ages)
# Out:
# [19.11260656 23.10294691 17.85250544 18.69377524 20.16380676 19.6348372
#  18.22675434 20.72102831 18.46111635 18.79715887 22.24396642 21.03453625
#  21.70344718 19.8832489  21.54720115 18.01134643 18.87113167 19.38401341
#  18.12125942 18.49056468 21.2332799  19.8260334  20.35874179 17.91877622
#  19.4520108  21.35241925 19.34545818 22.90771442 21.94250033 17.75727757
#  19.85671846 17.18825691 17.44790623 20.96521024 18.58117466 19.79844611
#  21.55309693 19.73777003 18.98807992 19.70180619 19.54693516 19.30021328
#  19.29671059 20.96620904 22.58948985 18.1717897  21.97535655 20.5551207
#  21.85541118 16.6582813  17.69290588 19.896263   24.3544209  23.49052275
#  19.75203197 17.72203363 20.41812353 17.27763895 19.65232258 23.92589714
#  21.74270185 23.09640286 24.891859   15.52400693 22.55430142 17.48427
#  20.10196976 17.29909236 19.79002548 21.40858242 19.21663254 18.10474268
#  20.86737682 17.45588277 19.59610135 18.06689567 17.15932105 18.94228184
# ...

# %%
ages.mean()
# Out:
# 19.909488201781553

# %%
# histogram with 12 bins and color = green
plt.hist(ages,bins=20,color='green')
plt.show()

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Piecharts are usefull in showing the ratios , this is sensefull only when the categories are not sharing anything in common.

# %%
languages = ['C','C++','Java','Python']
votes = [20,30,20,50]

# %%
plt.pie(votes,labels=languages)
plt.show()

# %% [markdown]
# ### Pie Chart Customizations

# %%
# We can explode certain pieces 0 to 1 including decimals
plt.pie(votes,labels=languages,explode=[0.5,0,0,0])
plt.show()

# %%
# for showing percentage
plt.pie(votes,labels=languages,explode=[0.3,0,0,0],autopct='%.2f%%') #'%.2f%%' is used to format a floating-point number as a percentage with two decimal places.
plt.show()

# %% [markdown]
# ### Box Plots
# ##### Box plot diagram is basically a statisical plot showing min , max , median and outliers

# %%
heights = np.random.normal(170,8,300)

# %%
import pandas as pd

# %%
df_heights = pd.DataFrame(heights)
df_heights.describe()
# Out:
#                 0
# count  300.000000
# mean   169.925656
# std      8.214550
# min    147.758740
# 25%    164.283394
# 50%    170.424549
# 75%    175.587724
# max    189.761779

# %%
plt.boxplot(heights)
plt.show()

# %% [markdown]
# ### General Plot Customizations

# %%
# creating custom data
years = [2000 + x for x in range(10)]
print(years)
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

# %%
income = [x+x**2 for x in range(5,15)]
print(income)
# Out:
# [30, 42, 56, 72, 90, 110, 132, 156, 182, 210]

# %%
plt.plot(years,income)
plt.title("Yearly Salary Growth",fontsize=25,color='red')
plt.xlabel("Year")
plt.ylabel("Income In Dollars ")
plt.show()

# %% [markdown]
# #### we can call plt.plot function multiple times and later on distuinguish between the plots using the legend function.

# %%
stock_a = np.random.randint(100,200,50)
stock_b = np.random.randint(150,220,50)
stock_c = np.random.randint(180,260,50)

plt.plot(stock_a,label='comp1')
plt.plot(stock_b,label='comp2')
plt.plot(stock_c,label='comp3')
plt.legend()
plt.show()

# %% [markdown]
# #### we can change the location of the legend
# ##### loc : str or pair of floats, default: :rc:`legend.loc`
# #####    The location of the legend.
#
# #####    The strings ``'upper left'``, ``'upper right'``, ``'lower left'``,
# #####    ``'lower right'`` place the legend at the corresponding corner of the
# #####    axes.
#
# #####    The strings ``'upper center'``, ``'lower center'``, ``'center left'``,
# #####    ``'center right'`` place the legend at the center of the corresponding edge
# #####    of the axes.
#
# #####    The string ``'center'`` places the legend at the center of the axes.
#
# #####    The string ``'best'`` places the legend at the location, among the nine
# #####    locations defined so far, with the minimum overlap with other drawn
# #####    artists.

# %%
plt.plot(stock_a, label = 'comp1')
plt.plot(stock_b, label = 'comp2')
plt.plot(stock_c, label = 'comp3')
plt.legend(loc='lower right')
plt.show()

# %%
# Using legend with pie chart
languages = ['C','C#','Python','Ruby','Kotlin']
votes = [10,12,39,21,18]
plt.pie(votes,labels=None) # here we setted the labels as none and instead of labels used legends
plt.legend(labels=languages)
plt.show()

# %% [markdown]
# ### Seaborn

# %% [markdown]
# Seaborn is a data visualization library built on top of matplotlib and closely integrated with pandas library.
# <br/>
# Graphs Available in Seaborn are :
# <br/>
# Scatter plot <br/>
# HeatMap <br/>
# Barplot<br/>
# Box Plot <br/>
# Violin Plot <br/>
# Swarm Plot <br/>
# Factor Plot <br/>
# And many more...

# %% [markdown]
# #### Seaborn Vs Matplotlib
# In MatplotLib the graphs have a pretty average look and feel , also there are les functionalities.<br/>
# Whereas in case of seaborn we can present the graphs in a more beautiful manner.

# %%
#importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#implenting it via matplot first 
x = np.random.randint(1,20,20)
y = np.random.randint(1,20,20)

# %%
print(x)
print('____________________________')
print(y)
# Out:
# [13  7  8 10 10 16  6 10  7  2  8  3  9  7 19 13  1 15  7  9]
# ____________________________
# [ 1  5  1 17 19 12 14  4 10 12 10 11  8  5  5  1  8  8  2  2]

# %%
# Now implementing it using seaborn 
# Note : Seaborn works on dataframe
# creating a dataframe first
my_data = pd.DataFrame({'x':x,'y':y})

# %%
my_data
# Out:
#      x   y
# 0   13   1
# 1    7   5
# 2    8   1
# 3   10  17
# 4   10  19
# 5   16  12
# 6    6  14
# 7   10   4
# 8    7  10
# 9    2  12
# 10   8  10
# 11   3  11
# 12   9   8
# 13   7   5
# 14  19   5
# 15  13   1
# 16   1   8
# 17  15   8
# 18   7   2
# 19   9   2

# %%
# for the lineplot we have the lineplot function 
sns.lineplot(x='x',y='y',data=my_data)
plt.title('Line Plot')
plt.show()

# %% [markdown]
# ##### Note: In Seaborn graph we have xlabels and ylabels

# %% [markdown]
# ### In order to use the seaborn data we have a funtion sns.load_dataset()

# %%
data = sns.load_dataset('penguins')
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data = data)
plt.show()

# %%
# to see the lineplot based on the species parameter 
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data = data,hue='species')
plt.show()

# %%
# changing the style based on species 
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data = data,hue='species',style='species')
plt.show()

# %%
#for applying a color theme use palette
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data = data,hue='sex',style='sex',palette='Accent')
plt.show()

# %%
# for applying the markers on the graph
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data = data,hue='sex',style='sex',markers=['o','>']) # two plots so two markers
plt.show()

# %%
# to remove the legend -- > legend = False
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data = data,hue='sex',style='sex',markers=['o','>'],legend=False)
plt.show()

# %% [markdown]
# ### Barplot

# %%
data.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
sns.barplot(x='species',y='body_mass_g',data = data)
plt.show()

# %%
# using hue to diffenrentiate between sex
sns.barplot(x='species',y='body_mass_g',data = data,hue='sex')
plt.show()

# %%
# we can also set the order here
order_to_follow = ['Gentoo','Chinstrap','Adelie']
sns.barplot(x='species',y='body_mass_g',data = data,hue='sex',order = order_to_follow)
plt.show()

# %% [markdown]
# ##### the black line on top of bargraphs are called ci , it ranges from 0 to 100 , at 0 it deminishes at 100 it becomes large enough

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.barplot(x='species',y='body_mass_g',data = data,hue='sex',order = order_to_follow,ci=50)
plt.show()

# %%
# for applying theme we use color palette
sns.barplot(x='species',y='body_mass_g',data = data,hue='sex',order = order_to_follow,palette='icefire')
plt.show()

# %%
# saturation makes the graph light or dark in color
sns.barplot(x='species',y='body_mass_g',data = data,hue='sex',order = order_to_follow,palette='icefire',saturation=0.4)
plt.show()

# %%
# we can apply the grid in our graph using matplotlib
sns.barplot(x='species',y='body_mass_g',data = data,hue='sex',order = order_to_follow,palette='icefire',saturation=0.7)
plt.grid()
plt.show()

# %%
# grid using seaborn
sns.set(style='darkgrid')
sns.barplot(x='species',y='body_mass_g',data = data,hue='sex',order = order_to_follow,palette='icefire')
plt.show()

# %% [markdown]
# ### Histogram

# %%
data.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
# for plotting the histogram we use displot() function
sns.displot(data['bill_length_mm'])
plt.show()

# %%
# we can increase the bin count 
sns.displot(data['bill_length_mm'],bins=20)
plt.show()

# %%
# plotting kde kernel density function
sns.displot(data['bill_length_mm'],kde=True)
plt.show()

# %%
# for changing the color we have to use the color parameter
sns.displot(data['bill_length_mm'],kde=True,color='red')
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
data.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
sns.scatterplot(x='bill_length_mm',y='bill_depth_mm',data=data)
plt.show()

# %%
# differentiating data based on sex
sns.scatterplot(x='bill_length_mm',y='bill_depth_mm',data=data,hue='sex')
plt.show()

# %%
# changing style
sns.scatterplot(x='bill_length_mm',y='bill_depth_mm',data=data,hue='sex',style='sex')
plt.show()

# %% [markdown]
# ### Heatmap Plot

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# ### Pair Plot

# %% [markdown]
# #### It will combine all the plots of the dataframe. Just pass the whole data

# %%
tips = sns.load_dataset('tips')

# %%
sns.pairplot(tips)
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#importing all the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#setting options to check max columns
pd.set_option('display.max_columns', None)

# %%
# loading the dataframe
loan_df = pd.read_csv(r"Datasets\loan.csv")

# %%
loan_df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  \
# 0       36 months   10.65%       162.87     B        B2
# ...

# %% [markdown]
# ### Exploring the dataframe

# %%
loan_df.info('display.max_columns')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    id                              int64
#  1    member_id                       int64
#  2    loan_amnt                       int64
#  3    funded_amnt                     int64
#  4    funded_amnt_inv                 float64
#  5    term                            object
#  6    int_rate                        object
#  7    installment                     float64
#  8    grade                           object
#  9    sub_grade                       object
#  10   emp_title                       object
#  11   emp_length                      object
#  12   home_ownership                  object
#  13   annual_inc                      float64
#  14   verification_status             object
#  15   issue_d                         object
# ...

# %%
#checking null values
loan_df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
# checking the shape of the dataframe
loan_df.shape
# Out:
# (39717, 111)

# %% [markdown]
# ##### No of rows = 39717 and nos of columns =111

# %%
loan_df.isnull().sum()==39717
# Out:
# id                            False
# member_id                     False
# loan_amnt                     False
# funded_amnt                   False
# funded_amnt_inv               False
#                               ...
# tax_liens                     False
# tot_hi_cred_lim                True
# total_bal_ex_mort              True
# total_bc_limit                 True
# total_il_high_credit_limit     True
# Length: 111, dtype: bool

# %%
#checking colulmns that have all the null value
columns_with_all_null_value = loan_df.columns[loan_df.isnull().sum()==39717]

# %%
columns_with_all_null_value
# Out:
# Index(['mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal',
#        'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal',
#        'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_inq', 'mths_since_recent_revol_delinq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m',
# ...

# %%
loan_df[columns_with_all_null_value].isnull().sum()
# Out:
# mths_since_last_major_derog       39717
# annual_inc_joint                  39717
# dti_joint                         39717
# verification_status_joint         39717
# tot_coll_amt                      39717
# tot_cur_bal                       39717
# open_acc_6m                       39717
# open_il_6m                        39717
# open_il_12m                       39717
# open_il_24m                       39717
# mths_since_rcnt_il                39717
# total_bal_il                      39717
# il_util                           39717
# open_rv_12m                       39717
# open_rv_24m                       39717
# max_bal_bc                        39717
# all_util                          39717
# total_rev_hi_lim                  39717
# inq_fi                            39717
# total_cu_tl                       39717
# inq_last_12m                      39717
# acc_open_past_24mths              39717
# avg_cur_bal                       39717
# ...

# %%
# dropping the above highlghted columns
loan_df.drop(columns=columns_with_all_null_value,inplace=True)

# %% [markdown]
# ### Now Let's explored the filtered data again

# %%
# checking the null count again
loan_df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12942
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %% [markdown]
# ### Conversion of data types for columns with Irregular type

# %% [markdown]
# #### column: term --> for how much time loan has been taken by the borrower

# %%
# checking for unique value in term column
loan_df['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
# converting the type of column for the calculation purpose
loan_df['term'] = loan_df['term'].str.replace('months','').astype(int)

# %%
#renaming `term` column to `term in months` for better understanding
loan_df.rename(columns = {'term' : 'term in months'},  inplace= True)

# %% [markdown]
# #### column: int_rate --> by what rate of interest loan was given

# %%
# checking for unique value in term column
loan_df['int_rate'].unique()
# Out:
# array(['10.65%', '15.27%', '15.96%', '13.49%', '12.69%', '7.90%',
#        '18.64%', '21.28%', '14.65%', '9.91%', '16.29%', '6.03%', '11.71%',
#        '12.42%', '14.27%', '16.77%', '7.51%', '8.90%', '18.25%', '6.62%',
#        '19.91%', '17.27%', '17.58%', '21.67%', '19.42%', '22.06%',
#        '20.89%', '20.30%', '23.91%', '19.03%', '23.52%', '23.13%',
#        '22.74%', '22.35%', '24.11%', '6.00%', '22.11%', '7.49%', '11.99%',
#        '5.99%', '10.99%', '9.99%', '18.79%', '11.49%', '8.49%', '15.99%',
#        '16.49%', '6.99%', '12.99%', '15.23%', '14.79%', '5.42%', '10.59%',
#        '17.49%', '15.62%', '21.36%', '19.29%', '13.99%', '18.39%',
#        '16.89%', '17.99%', '20.62%', '20.99%', '22.85%', '19.69%',
#        '20.25%', '23.22%', '21.74%', '22.48%', '23.59%', '12.62%',
#        '18.07%', '11.63%', '7.91%', '7.42%', '11.14%', '20.20%', '12.12%',
#        '19.39%', '16.11%', '17.54%', '22.64%', '13.84%', '16.59%',
# ...

# %%
# replacing % sign from the column
loan_df['int_rate'] = loan_df['int_rate'].str.replace('%', '').astype('float')

# %% [markdown]
# #### column: emp_length --> for how long borrower is working

# %%
loan_df['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
loan_df['emp_length'] = loan_df['emp_length'].str.replace('years','').str.replace('year','')

# %%
loan_df['emp_length'].unique()
# Out:
# array(['10+ ', '< 1 ', '1 ', '3 ', '8 ', '9 ', '4 ', '5 ', '6 ', '2 ',
#        '7 ', nan], dtype=object)

# %%
# replacing `< ` and `+` from column
loan_df['emp_length'] = loan_df['emp_length'].str.replace('+', '').str.replace('< ', '')

# %%
# filling nan values with -1 value for ease and understanding
loan_df['emp_length'] = loan_df['emp_length'].fillna(-1)

# %%
#converting type of column for calculation purpose
loan_df['emp_length'] = loan_df['emp_length'].astype(int)

# %%
loan_df['emp_length'].unique()
# Out:
# array([10,  1,  3,  8,  9,  4,  5,  6,  2,  7, -1])

# %% [markdown]
# #### column: issue_d --> on which month the loan was given

# %%
#checking for unique value
loan_df['issue_d'].unique()
# Out:
# array(['Dec-11', 'Nov-11', 'Oct-11', 'Sep-11', 'Aug-11', 'Jul-11',
#        'Jun-11', 'May-11', 'Apr-11', 'Mar-11', 'Feb-11', 'Jan-11',
#        'Dec-10', 'Nov-10', 'Oct-10', 'Sep-10', 'Aug-10', 'Jul-10',
#        'Jun-10', 'May-10', 'Apr-10', 'Mar-10', 'Feb-10', 'Jan-10',
#        'Dec-09', 'Nov-09', 'Oct-09', 'Sep-09', 'Aug-09', 'Jul-09',
#        'Jun-09', 'May-09', 'Apr-09', 'Mar-09', 'Feb-09', 'Jan-09',
#        'Dec-08', 'Nov-08', 'Oct-08', 'Sep-08', 'Aug-08', 'Jul-08',
#        'Jun-08', 'May-08', 'Apr-08', 'Mar-08', 'Feb-08', 'Jan-08',
#        'Dec-07', 'Nov-07', 'Oct-07', 'Sep-07', 'Aug-07', 'Jul-07',
#        'Jun-07'], dtype=object)

# %%
loan_df['issue_d'] = pd.to_datetime(loan_df['issue_d'],format='%b-%y')

# %%
#checking the result
loan_df['issue_d'].unique()
# Out:
# <DatetimeArray>
# ['2011-12-01 00:00:00', '2011-11-01 00:00:00', '2011-10-01 00:00:00',
#  '2011-09-01 00:00:00', '2011-08-01 00:00:00', '2011-07-01 00:00:00',
#  '2011-06-01 00:00:00', '2011-05-01 00:00:00', '2011-04-01 00:00:00',
#  '2011-03-01 00:00:00', '2011-02-01 00:00:00', '2011-01-01 00:00:00',
#  '2010-12-01 00:00:00', '2010-11-01 00:00:00', '2010-10-01 00:00:00',
#  '2010-09-01 00:00:00', '2010-08-01 00:00:00', '2010-07-01 00:00:00',
#  '2010-06-01 00:00:00', '2010-05-01 00:00:00', '2010-04-01 00:00:00',
#  '2010-03-01 00:00:00', '2010-02-01 00:00:00', '2010-01-01 00:00:00',
#  '2009-12-01 00:00:00', '2009-11-01 00:00:00', '2009-10-01 00:00:00',
#  '2009-09-01 00:00:00', '2009-08-01 00:00:00', '2009-07-01 00:00:00',
#  '2009-06-01 00:00:00', '2009-05-01 00:00:00', '2009-04-01 00:00:00',
#  '2009-03-01 00:00:00', '2009-02-01 00:00:00', '2009-01-01 00:00:00',
#  '2008-12-01 00:00:00', '2008-11-01 00:00:00', '2008-10-01 00:00:00',
# ...

# %% [markdown]
# #### column: earliest_cr_line --> on which month the first credit line was open

# %%
#checking for unique value
loan_df['earliest_cr_line'].unique()
# Out:
# array(['Jan-85', 'Apr-99', 'Nov-01', 'Feb-96', 'Jan-96', 'Nov-04',
#        'Jul-05', 'Jan-07', 'Apr-04', 'Sep-04', 'Jan-98', 'Oct-89',
#        'Jul-03', 'May-91', 'Sep-07', 'Oct-98', 'Aug-93', 'Oct-03',
#        'Jan-01', 'Nov-97', 'Feb-83', 'Jul-85', 'Apr-03', 'Jun-01',
#        'Feb-02', 'Aug-84', 'Nov-06', 'Dec-87', 'Nov-81', 'Feb-97',
#        'Apr-05', 'Oct-07', 'Dec-00', 'Apr-07', 'Dec-01', 'Jan-03',
#        'Mar-94', 'Sep-98', 'Jun-04', 'Nov-95', 'Jul-99', 'Jun-95',
#        'Sep-92', 'Jan-02', 'Apr-92', 'Oct-06', 'May-00', 'Dec-98',
#        'Dec-04', 'Oct-00', 'May-02', 'May-06', 'Jul-02', 'Jul-06',
#        'May-97', 'Oct-05', 'Apr-95', 'Oct-02', 'Jan-00', 'Apr-00',
#        'Dec-94', 'Sep-05', 'Dec-84', 'Dec-99', 'Nov-03', 'Jun-89',
#        'Jun-03', 'Oct-96', 'May-03', 'Jun-02', 'Jun-07', 'Dec-96',
#        'Feb-84', 'Sep-02', 'Jan-86', 'May-98', 'Jan-97', 'Jun-05',
#        'Feb-90', 'Mar-04', 'Jul-95', 'Aug-94', 'Jun-92', 'Mar-97',
# ...

# %%
loan_df['earliest_cr_line'] = pd.to_datetime(loan_df['earliest_cr_line'],format='%b-%y')

# %%
loan_df['earliest_cr_line'].unique()
# Out:
# <DatetimeArray>
# ['1985-01-01 00:00:00', '1999-04-01 00:00:00', '2001-11-01 00:00:00',
#  '1996-02-01 00:00:00', '1996-01-01 00:00:00', '2004-11-01 00:00:00',
#  '2005-07-01 00:00:00', '2007-01-01 00:00:00', '2004-04-01 00:00:00',
#  '2004-09-01 00:00:00',
#  ...
#  '2067-05-01 00:00:00', '2061-11-01 00:00:00', '2067-02-01 00:00:00',
#  '2068-11-01 00:00:00', '1975-10-01 00:00:00', '1971-03-01 00:00:00',
#  '1971-08-01 00:00:00', '2066-12-01 00:00:00', '2068-10-01 00:00:00',
#  '1974-10-01 00:00:00']
# Length: 526, dtype: datetime64[ns]

# %% [markdown]
# #### column: desc --> description given by borrower why loan has been taken

# %%
#checking for unique value
loan_df['desc'].unique()
# Out:
# array(['  Borrower added on 12/22/11 > I need to upgrade my business technologies.<br>',
#        '  Borrower added on 12/22/11 > I plan to use this money to finance the motorcycle i am looking at. I plan to have it paid off as soon as possible/when i sell my old bike. I only need this money because the deal im looking at is to good to pass up.<br><br>  Borrower added on 12/22/11 > I plan to use this money to finance the motorcycle i am looking at. I plan to have it paid off as soon as possible/when i sell my old bike.I only need this money because the deal im looking at is to good to pass up. I have finished college with an associates degree in business and its takingmeplaces<br>',
#        nan, ...,
#        'Our current gutter system on our home is old and in need of repair.    We will be using the borrowed funds to replace the gutter system on our home.',
# ...

# %%
# filling nan with `borrower donot give any description` for better understanding
loan_df['desc'] = loan_df['desc'].fillna('borrower didnot give any description')

# %% [markdown]
# #### column: purpose --> purpose as described by the lender company

# %%
#checking for unique value
loan_df['purpose'].unique()
# Out:
# array(['credit_card', 'car', 'small_business', 'other', 'wedding',
#        'debt_consolidation', 'home_improvement', 'major_purchase',
#        'medical', 'moving', 'vacation', 'house', 'renewable_energy',
#        'educational'], dtype=object)

# %%
# column looks good

# %% [markdown]
# #### column: title --> title given by lender company

# %%
#checking for unique value
loan_df['title'].unique()
# Out:
# array(['Computer', 'bike', 'real estate business', ...,
#        'Retiring credit card debt', 'MBA Loan Consolidation', 'JAL Loan'],
#       dtype=object)

# %%
# checking for number of null values
loan_df['title'].isnull().sum()
# Out:
# 11

# %%
# filling nan with `no title given` for better understanding
loan_df['title'] = loan_df['title'].fillna('no title given')

# %% [markdown]
# #### column: zip_code --> address zipcode

# %%
#checking for unique value
loan_df['zip_code'].unique()
# Out:
# array(['860xx', '309xx', '606xx', '917xx', '972xx', '852xx', '280xx',
#        '900xx', '958xx', '774xx', '853xx', '913xx', '245xx', '951xx',
#        '641xx', '921xx', '067xx', '890xx', '770xx', '335xx', '799xx',
#        '605xx', '103xx', '150xx', '326xx', '564xx', '141xx', '080xx',
#        '330xx', '974xx', '934xx', '405xx', '946xx', '445xx', '850xx',
#        '604xx', '292xx', '088xx', '180xx', '029xx', '700xx', '010xx',
#        '441xx', '104xx', '061xx', '616xx', '947xx', '914xx', '765xx',
#        '980xx', '017xx', '752xx', '787xx', '077xx', '540xx', '225xx',
#        '440xx', '437xx', '559xx', '912xx', '325xx', '300xx', '923xx',
#        '352xx', '013xx', '146xx', '074xx', '786xx', '937xx', '331xx',
#        '115xx', '191xx', '114xx', '908xx', '902xx', '992xx', '750xx',
#        '950xx', '329xx', '226xx', '614xx', '802xx', '672xx', '083xx',
#        '100xx', '926xx', '931xx', '712xx', '060xx', '707xx', '342xx',
# ...

# %%
# removing 'xx' from zip code
loan_df['zip_code'] = loan_df['zip_code'].str.replace('xx', '').astype(int)

# %% [markdown]
# #### column: emp_title --> employee designation of the borrower

# %%
#checking number of null values
loan_df['emp_title'].isnull().sum()
# Out:
# 2459

# %%
loan_df['emp_title'].unique()
# Out:
# array([nan, 'Ryder', 'AIR RESOURCES BOARD', ..., 'FiSite Research',
#        'Squarewave Solutions, Ltd.', 'Evergreen Center'], dtype=object)

# %%
# converting nan with `either not working or self employed` for better understanding
loan_df['emp_title'] = loan_df['emp_title'].fillna('either not working or self employed')

# %% [markdown]
# #### column: mths_since_last_delinq --> month when last deliquency has been done by borrower

# %%
loan_df['mths_since_last_delinq'].unique()
# Out:
# array([ nan,  35.,  38.,  61.,   8.,  20.,  18.,  68.,  45.,  48.,  41.,
#         40.,  74.,  25.,  53.,  39.,  10.,  26.,  56.,  77.,  28.,  52.,
#         24.,  16.,  60.,  54.,  23.,   9.,  11.,  13.,  65.,  19.,  80.,
#         22.,  59.,  79.,  44.,  64.,  57.,  14.,  63.,  49.,  15.,  73.,
#         70.,  29.,  51.,   5.,  75.,  55.,   2.,  30.,  47.,  33.,  69.,
#          4.,  43.,  21.,  27.,  46.,  81.,  78.,  82.,  31.,  76.,  62.,
#         72.,  42.,  50.,   3.,  12.,  67.,  36.,  34.,  58.,  17.,  71.,
#         66.,  32.,   6.,  37.,   7.,   1.,  83.,  86., 115.,  96., 103.,
#        120., 106.,  89., 107.,  85.,  97.,  95.,   0.])

# %%
# giving value of -1 for better understanding and later will help in plotting too
loan_df['mths_since_last_delinq']=loan_df['mths_since_last_delinq'].fillna(-1)

# %%
#converting column to int
loan_df['mths_since_last_delinq'] = loan_df['mths_since_last_delinq'].astype(int)

# %% [markdown]
# #### column: mths_since_last_record --> month since last public record

# %%
# checking unique value
loan_df['mths_since_last_record'].unique()
# Out:
# array([ nan, 113., 105.,  97.,  33.,  93.,  52.,  85.,  90.,  91., 114.,
#         92., 117.,  87.,  45.,  83., 118.,  38., 101., 100., 112., 110.,
#         88.,  79.,  77., 107., 102.,  98.,  95., 103.,  96., 116., 111.,
#         89., 108.,  29., 106., 115.,  53.,  86.,  57.,  63.,  94., 109.,
#         99., 104.,  76.,  61.,  28.,  23.,  75.,  47.,  82.,  21.,  62.,
#         44.,  80.,  67., 119.,  42.,  34.,  66.,  58.,  22.,  56.,  72.,
#         64.,  50.,  69.,  49.,  74.,  35.,  12.,  26.,  78.,  54.,  37.,
#         73.,  11.,  31.,  59.,  32.,  81.,  68.,  55.,  39.,  51.,  70.,
#         30.,  41.,  71.,  40.,  43.,  27.,  65.,  46.,  19.,  17.,  25.,
#         13.,  48.,  36.,   7.,  60.,  14.,   6.,  18.,   0.,  20., 120.,
#        129.,   5.])

# %%
# filling `-1` in nan value for our understanding meaning no past bad public record
loan_df['mths_since_last_record'] = loan_df['mths_since_last_record'].fillna(-1)

# %%
#converting column to int
loan_df['mths_since_last_record'] = loan_df['mths_since_last_record'].astype(int)

# %% [markdown]
# #### column: revol_util --> what % of revol balance is the borrower using

# %%
# checking unique value
loan_df['revol_util'].unique()
# Out:
# array(['83.70%', '9.40%', '98.50%', ..., '49.63%', '0.04%', '7.28%'],
#       dtype=object)

# %%
#checking nan value
loan_df['revol_util'].isnull().sum()
# Out:
# 50

# %%
# removing % from column
loan_df['revol_util'] = loan_df['revol_util'].str.replace('%','')

# %%
#fill nan with -1 for our ease
loan_df['revol_util'] = loan_df['revol_util'].fillna(-1)

# %%
# converting column to float
loan_df['revol_util'] = loan_df['revol_util'].astype(float)

# %%
#renaming `revol_util` column to `revol_util in %` for better understanding
loan_df.rename(columns = {'revol_util' : 'revol_util in %'},  inplace= True)

# %% [markdown]
# #### column: last_pymnt_d --> when was the last installment was given

# %%
loan_df['last_pymnt_d'] = pd.to_datetime(loan_df['last_pymnt_d'], format= '%b-%y')

# %%
# checking the loan status for the rows that have last_pymt_d as nan
loan_df[(loan_df['last_pymnt_d'].isna())]['loan_status'].unique()
# Out:
# array(['Charged Off'], dtype=object)

# %%
#converting to datetime
loan_df['last_pymnt_d'] = pd.to_datetime(loan_df['last_pymnt_d'], format= '%b-%y')

# %%
# since all of the null values are already charged off we can give them -1 for our understanding
loan_df['last_pymnt_d']= loan_df['last_pymnt_d'].fillna(-1)

# %% [markdown]
# #### column: next_pymnt_d --> when is the next payment due

# %%
# checking the loan status for the rows that have next_pymt_d as nan
loan_df[(loan_df['next_pymnt_d'].isna())]['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
#converting to datetime
loan_df['next_pymnt_d'] = pd.to_datetime(loan_df['next_pymnt_d'], format= '%b-%y')

# %%
# since all of the null values are already charged off or fully paid we can give them -1 for our understanding
loan_df['next_pymnt_d']= loan_df['next_pymnt_d'].fillna(-1)

# %% [markdown]
# #### column: last_credit_pull_d --> when is the last credit was pulled

# %%
loan_df[loan_df['last_credit_pull_d'].isna()]
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 26025  575712     740467       5000         5000           5000.0
# 39476  186499     186347       1000         1000            875.0
#
#        term in months  int_rate  installment grade sub_grade  \
# 26025              36     11.12       163.98     B        B3
# 39476              36      7.12        30.94     A        A1
#
#                                  emp_title  emp_length home_ownership  \
# 26025  either not working or self employed           5           RENT
# 39476  either not working or self employed           1       MORTGAGE
#
#        annual_inc verification_status    issue_d  loan_status pymnt_plan  \
# 26025     96000.0        Not Verified 2010-09-01  Charged Off          n
# 39476    120000.0        Not Verified 2007-12-01   Fully Paid          n
#
#                                                      url  \
# 26025  https://lendingclub.com/browse/loanDetail.acti...
# ...

# %%
loan_df['last_credit_pull_d'].unique()
# Out:
# array(['May-16', 'Sep-13', 'Apr-16', 'Jan-16', 'Dec-14', 'Aug-12',
#        'Mar-13', 'Dec-15', 'Aug-13', 'Nov-12', 'Mar-14', 'Apr-15',
#        'May-14', 'Jul-15', 'Feb-16', 'Mar-16', 'Sep-12', 'May-13',
#        'Jan-15', 'Jun-12', 'Mar-15', 'Dec-12', 'Sep-14', 'Feb-14',
#        'Jun-15', 'Oct-13', 'Apr-14', 'Oct-14', 'Feb-13', 'Nov-15',
#        'Jul-14', 'Sep-15', 'Oct-12', 'Nov-13', 'Nov-14', 'Feb-12',
#        'Oct-15', 'Apr-12', 'Aug-15', 'Jun-14', 'Jan-12', 'Aug-14',
#        'Jun-13', 'Dec-13', 'May-12', 'Jul-12', 'Jan-14', 'Jul-13',
#        'Apr-13', 'May-15', 'Feb-15', 'Mar-12', 'Nov-11', 'Dec-11',
#        'Jan-13', 'Oct-11', 'Sep-11', 'Aug-11', 'Jul-11', 'Jun-11',
#        'May-11', 'Apr-11', 'Mar-11', 'Feb-11', 'Jan-11', 'Dec-10',
#        'Nov-10', 'Oct-10', nan, 'Sep-10', 'Aug-10', 'Jul-10', 'Jun-10',
#        'May-10', 'Apr-10', 'Feb-10', 'Mar-10', 'Aug-07', 'Jan-10',
#        'Dec-09', 'Nov-09', 'Oct-09', 'Sep-09', 'Jul-09', 'Aug-09',
# ...

# %% [markdown]
# #### column: collections_12_mths_ex_med --> recovery after charged off after 12 months

# %%
#checking unique value
loan_df['collections_12_mths_ex_med'].unique()
# Out:
# array([ 0., nan])

# %% [markdown]
# ##### we can drop this column as not adding any value to our data

# %%
loan_df.drop(columns=['collections_12_mths_ex_med'],inplace=True)

# %% [markdown]
# #### column: pub_rec_bankruptcies --> if any record of bankruptcies

# %%
#checking unique value
loan_df['pub_rec_bankruptcies'].unique()
# Out:
# array([ 0.,  1.,  2., nan])

# %%
#  fillling -1 for nan to better understanding
loan_df['pub_rec_bankruptcies'] = loan_df['pub_rec_bankruptcies'].fillna(-1)

# %% [markdown]
# #### column: chargeoff_within_12_mths --> recovery after charged off within 12 months

# %%
#checking unique value
loan_df['chargeoff_within_12_mths'].unique()
# Out:
# array([ 0., nan])

# %% [markdown]
# #### column: tax_liens --> any number of tax liens by government

# %%
#checking unique value
loan_df['tax_liens'].unique()
# Out:
# array([ 0., nan])

# %% [markdown]
# #### column: acc_now_delinq

# %%
#checking unique value
loan_df['acc_now_delinq'].unique()
# Out:
# array([0], dtype=int64)

# %%
#dropping column that are not adding any value
loan_df = loan_df.drop(columns= ['tax_liens', 'chargeoff_within_12_mths',  'acc_now_delinq'])

# %% [markdown]
# #### Column : initial_list_status

# %%
#dropping this column as all have the same value hence initial_list_status
loan_df = loan_df.drop(columns= ['initial_list_status'])

# %%
# resetting the index
loan_df.reset_index(drop= True, inplace= True)

# %% [markdown]
# ## Visual Analysis

# %% [markdown]
# ### Defining a is_defaulter column where 1 means defaulter and 0 means not a defaulter

# %%
loan_df['is_defaulter'] = loan_df['loan_status'].apply(lambda x: 1 if x == 'Charged Off' else 0)

# %% [markdown]
# ### Graphical representation of the type of loan_status to see how many have been charged off

# %%
sns.countplot(data = loan_df, x= 'loan_status')
plt.title('Loan Status Distribution')
plt.xlabel('Types of loan status')
plt.ylabel('Count of each type')
plt.show()

# %% [markdown]
# #### Observation : we have almost 1/8 defaulters out off total data

# %% [markdown]
# ## exploring loan_amnt column

# %%
sns.boxplot(data = loan_df, y='loan_amnt',hue='is_defaulter')
plt.title('Distribution of loan amount')
plt.ylabel('loan amount')
plt.xlabel('Is Defaulter')
plt.show()

# %% [markdown]
# #### Observation : we can see that there are outliers lets see if that can make any relation with the defaulters

# %%
# calculating the upper whisker for loan amount
loan_amount_75th_percentile = loan_df['loan_amnt'].quantile(0.75)
loan_amount_25th_percentile = loan_df['loan_amnt'].quantile(0.25)
iqr_loan_amount = loan_amount_75th_percentile - loan_amount_25th_percentile
upperwhisker_value = loan_amount_75th_percentile + (1.5 * iqr_loan_amount)

# %%
loan_df[loan_df['loan_amnt'] > upperwhisker_value]['is_defaulter'].value_counts()
# Out:
# is_defaulter
# 0    977
# 1    253
# Name: count, dtype: int64

# %% [markdown]
# #### Observation : we can see that the borrower taking loan > 29250 is less likely to make default.

# %% [markdown]
# ### Now lets check grade Column

# %%
sns.countplot(data = loan_df, x = 'grade')
plt.title('Number of loans per grade')
plt.xlabel('Grade')
plt.ylabel('Loan Count')
plt.show()

# %% [markdown]
# #### Observation : We can see clearly that less loan has been given to grade E, F, G

# %% [markdown]
# #### Lets check  defaulters relationship here

# %%
sns.countplot(data = loan_df, x = 'grade',  hue = loan_df['is_defaulter'].astype(str))
plt.title('Number of loans per grade vs Number of defaulter in that grade')
plt.xlabel('Grade vs Defaulter')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Observation : we can clearly see that grading system have clearly reduce the defaulter percentage.

# %% [markdown]
# ### Now explore sub_grade

# %%
plt.figure(figsize=(12,6))
sns.countplot(data = loan_df, x = 'sub_grade', order= sorted(loan_df['sub_grade'].unique()),hue='is_defaulter')
plt.title('Number of loans per  sub grade')
plt.xlabel('Sub Grade')
plt.ylabel('Loan Count')
plt.show()

# %% [markdown]
# #### Observation : We can observe a trend where the number of loans approved decreases as we move into the riskier category also max nos of defaulters are in B5 Category

# %% [markdown]
# #### Observation2 : We can see that there is good affect of grading and subgrading, we can conclude that we should avoid giving loan to riskier client but its not very conclusive lets dive further.

# %% [markdown]
# ### Checking whether a higher debt-to-income ratio (dti) is associated with higher default rates

# %%
# dti : A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
plt.figure(figsize=[10,6])
sns.boxplot(x='is_defaulter',y='dti',data=loan_df,hue='is_defaulter')
plt.title('DTI Comaprison for Defaulter Vs Non Defaulter')
plt.xlabel('IS Defaulter')
plt.ylabel('DTI')
plt.show()

# %% [markdown]
# #### there’s a slight upward shift in the DTI range for defaulters, indicating that defaulters might have a marginally higher debt-to-income ratio than non-defaulters.

# %%
defaulter_grouped_data=loan_df.groupby('is_defaulter')

# %%
defaulter_grouped_data['dti'].describe()
# Out:
#                 count       mean       std  min   25%    50%    75%    max
# is_defaulter
# 0             34090.0  13.201980  6.687165  0.0  8.04  13.25  18.46  29.99
# 1              5627.0  14.000624  6.585577  0.0  9.05  14.29  19.29  29.85

# %% [markdown]
# IQR FOR IS_DEFAULTER = 0 -> 18.46-8.04 = 10.42 <br/>
# IQR FOR IS_DEFAULTER = 1 -> 19.29-9.05 = 10.24

# %% [markdown]
# #### The median DTI for defaulters (14.29) is slightly higher than that for non-defaulters (13.25), indicating that defaulters, on average, carry a marginally higher debt load relative to their income.
# #### Even though there is a slightly higher DTI among defaulters, the overlap in the IQR suggests that DTI alone is not a clear distinguishing factor for defaults.

# %% [markdown]
# ## Checking Relation Between Defaulter VS InterestRate (int_rate)

# %%
plt.figure(figsize=[10,6])
sns.boxplot(x='is_defaulter',y='int_rate',data=loan_df,hue='is_defaulter')
plt.title("Interest Rate Comparison For Defaulter Vs Non Defaulter")
plt.xlabel("Is Defaulter")
plt.ylabel("Interest Rate")
plt.show()

# %%
defaulter_grouped_data['int_rate'].describe()
# Out:
#                 count       mean       std   min    25%    50%    75%    max
# is_defaulter
# 0             34090.0  11.724186  3.652109  5.42   8.88  11.49  14.17  24.59
# 1              5627.0  13.820432  3.654413  5.42  11.31  13.61  16.40  24.40

# %% [markdown]
# IQR FOR IS_DEFAULTER = 0 -> 14.17-8.88 = 5.29<br/>
# IQR FOR IS_DEFAULTER = 1 -> 16.40-11.31 = 5.09

# %% [markdown]
# #### The mean interest rate for defaulters (13.82%) is higher than for non-defaulters (11.72%), indicating that loans with higher interest rates are more likely to default.
# #### The median interest rate for defaulters (13.61%) is also higher than for non-defaulters (11.49%).
# #### Higher interest rates might be a strong indicator of default risk, possibly because higher rates are assigned to applicants with higher risk profiles.
# #### This relationship can be useful for risk assessment, suggesting that loans with interest rates above a certain threshold might need closer monitoring.

# %% [markdown]
# ## Checking the verification_status Column for Defaulters Only

# %%
loan_df['verification_status'].unique()
# Out:
# array(['Verified', 'Source Verified', 'Not Verified'], dtype=object)

# %%
plt.figure(figsize=[12,6])
sns.countplot(x='verification_status',data=loan_df[loan_df['is_defaulter']==1])
plt.title('Verification Status of Defaulters')
plt.xlabel('Verification Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Observation : The count of Not Verified Applicants are higher as compared to to the Verified Applicants

# %% [markdown]
# ## Checking the Loan Purpose VS Defaulters

# %%
loan_df['purpose'].unique()
# Out:
# array(['credit_card', 'car', 'small_business', 'other', 'wedding',
#        'debt_consolidation', 'home_improvement', 'major_purchase',
#        'medical', 'moving', 'vacation', 'house', 'renewable_energy',
#        'educational'], dtype=object)

# %%
plt.figure(figsize=[12,8])
sns.countplot(data=loan_df[loan_df['is_defaulter']==1],x='purpose')
plt.title('Comparison for Loan Purpose for Defaulter Vs Non Defaulter')
plt.xlabel('Purpose')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# numerical analysis
loan_df[loan_df['is_defaulter']==1]['purpose'].value_counts()

# %% [markdown]
# ### Cases where the purpose of taking loan was debt_consolidation has seen the major number of defaulters as compared to other categories. So we need to adjust the policies and interest rates for this category specially.

# %% [markdown]
# ### Correlation Between Columns 'loan_amnt', 'annual_inc', 'dti', 'int_rate', 'is_defaulter'

# %%
cols = ['loan_amnt', 'annual_inc', 'dti', 'int_rate', 'is_defaulter']
corr_matrix = loan_df[cols].corr()
print(corr_matrix)
# Out:
#               loan_amnt  annual_inc       dti  int_rate  is_defaulter
# loan_amnt      1.000000    0.271149  0.066439  0.309415      0.048217
# annual_inc     0.271149    1.000000 -0.122732  0.053185     -0.041662
# dti            0.066439   -0.122732  1.000000  0.111162      0.041701
# int_rate       0.309415    0.053185  0.111162  1.000000      0.196253
# is_defaulter   0.048217   -0.041662  0.041701  0.196253      1.000000

# %%
sns.heatmap(corr_matrix,cmap='coolwarm',annot=True)
plt.title("Heatmap Comparison For Correlation Matrix")
plt.show()

# %% [markdown]
# #### The most meaningful finding here is the relationship between int_rate and is_defaulter, which can be used as a potential indicator of default risk.
# #### There is a strong relationship between the loan_amnt column and the annual_inc column (0.27) suggesting that borrowers with higher incomes tend to take larger loans.
# #### Strong relation between loan_amnt and int_rate hence larger loan_amnt will attract more interest.
# #### Although other correlations are weak, they can still be considered as part of a multivariate analysis to explore complex relationships.

# %% [markdown]
# ## Pairplots for columns having correlation > 0.2 with IS_DEFAULTER Column

# %%
loan_df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term in months', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url',
#        'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util in %', 'total_acc', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'policy_code', 'application_type',
#        'delinq_amnt', 'pub_rec_bankruptcies', 'is_defaulter'],
#       dtype='object')

# %%
corr_matrix = loan_df.corr(numeric_only=True)

# %%
corr_matrix
# Out:
#                                id  member_id  loan_amnt  funded_amnt  \
# id                       1.000000   0.993650   0.141919     0.152286
# member_id                0.993650   1.000000   0.140710     0.150322
# loan_amnt                0.141919   0.140710   1.000000     0.981578
# funded_amnt              0.152286   0.150322   0.981578     1.000000
# funded_amnt_inv          0.249547   0.257887   0.940034     0.958422
# term in months           0.218589   0.234265   0.361036     0.340510
# int_rate                 0.078831   0.074725   0.309415     0.312619
# installment              0.086587   0.081025   0.930288     0.956159
# emp_length               0.090912   0.094105   0.162658     0.162207
# annual_inc               0.008731   0.009380   0.271149     0.266965
# zip_code                 0.017561   0.015950  -0.002120    -0.002445
# dti                      0.095983   0.096963   0.066439     0.066283
# delinq_2yrs             -0.008644  -0.008119  -0.031864    -0.032355
# ...

# %%
corr_matrix['is_defaulter']
# Out:
# id                         0.028370
# member_id                  0.026438
# loan_amnt                  0.048217
# funded_amnt                0.045544
# funded_amnt_inv            0.026621
# term in months             0.146038
# int_rate                   0.196253
# installment                0.022589
# emp_length                 0.002429
# annual_inc                -0.041662
# zip_code                   0.018128
# dti                        0.041701
# delinq_2yrs                0.019904
# inq_last_6mths             0.071717
# mths_since_last_delinq     0.020431
# mths_since_last_record     0.053277
# open_acc                  -0.010742
# pub_rec                    0.050880
# revol_bal                  0.003369
# revol_util in %            0.095118
# total_acc                 -0.023563
# out_prncp                 -0.055476
# out_prncp_inv             -0.055417
# total_pymnt               -0.238844
# total_pymnt_inv           -0.236232
# total_rec_prncp           -0.335019
# ...

# %%
corr_matrix

# %%
corr_matrix[corr_matrix['is_defaulter']>0.2]
# Out:
#                                id  member_id  loan_amnt  funded_amnt  \
# recoveries               0.033426   0.031565   0.135446     0.136284
# collection_recovery_fee -0.013359  -0.015155   0.072853     0.074676
# is_defaulter             0.028370   0.026438   0.048217     0.045544
#
#                          funded_amnt_inv  term in months  int_rate  \
# recoveries                      0.123759        0.101351  0.122259
# collection_recovery_fee         0.060358        0.031731  0.066380
# is_defaulter                    0.026621        0.146038  0.196253
#
#                          installment  emp_length  annual_inc  zip_code  \
# recoveries                  0.118152    0.024810    0.021589  0.001511
# collection_recovery_fee     0.075467    0.006486    0.015604  0.001914
# is_defaulter                0.022589    0.002429   -0.041662  0.018128
#
#                               dti  delinq_2yrs  inq_last_6mths  \
# recoveries               0.024878     0.012315        0.018972
# ...

# %%
corr_matrix[corr_matrix['is_defaulter']>0.2]['is_defaulter'].index.to_list()
# Out:
# ['recoveries', 'collection_recovery_fee', 'is_defaulter']

# %%
corr_column = corr_matrix[corr_matrix['is_defaulter']>0.2]['is_defaulter'].index.to_list()

# %% [markdown]
# #### recoveries : post charge off gross recovery ("Post charge-off gross recovery" refers to the amount of money collected from a debt after it has been charged off by a lender)
# #### collection_recovery_fee: post charge off collection fee (A "post charge-off collection fee" is an additional fee that a lender may charge after a debt has been charged off.)

# %%
sns.pairplot(loan_df[corr_column] , hue='is_defaulter')
plt.show()

# %% [markdown]
# ### Observation
# #### Collection_recovery_fee and recoveries have a high positive correlation. Generally speaking, the collection recovery charge rises in tandem with the number of recoveries. Because of the linear nature of this connection, larger recoveries are linked to higher collection fees.
# #### Higher values of recoveries and collection_recovery_fee cluster the majority of defaulters (is_defaulter = 1). This suggests that, in comparison to non-defaulters, defaulters frequently have larger recovery amounts and related expenses.

# %%
plt.figure(figsize=[12,8])
plt.title('Address State Comparison For Defaulters')
sns.countplot(data=loan_df[loan_df['is_defaulter']==1],x='addr_state',color='red')
plt.xlabel('State')
plt.ylabel('Defaulters Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Observation : Maximum number of defaulters are coming from states CA , FL , NY...
